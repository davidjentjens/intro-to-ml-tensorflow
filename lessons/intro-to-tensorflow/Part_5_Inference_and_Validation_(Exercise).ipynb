# %% [markdown]
# # Inference and Validation
#
# Now that you have a trained network, you can use it for making predictions. This is typically called **inference**, a term borrowed from statistics. However, neural networks have a tendency to perform *too well* on the training data and aren't able to generalize to data that hasn't been seen before. This is called **overfitting** and it impairs inference performance. To test for overfitting while training, we measure the performance on data not in the training set called the **validation** set. We avoid overfitting through regularization such as dropout while monitoring the validation performance during training.

# %% [markdown]
# ## Import Resources

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import numpy as np
import matplotlib.pyplot as plt

import tensorflow as tf
import tensorflow_datasets as tfds
tfds.disable_progress_bar()

# %%
import logging
logger = tf.get_logger()
logger.setLevel(logging.ERROR)

# %%
print('Using:')
print('\t\u2022 TensorFlow version:', tf.__version__)
print('\t\u2022 tf.keras version:', tf.keras.__version__)
print('\t\u2022 Running on GPU' if tf.test.is_gpu_available() else '\t\u2022 GPU device not found. Running on CPU')
# Out:
# Using:
# 	• TensorFlow version: 2.4.0
# 	• tf.keras version: 2.4.0
# 	• GPU device not found. Running on CPU

# %% [markdown]
# ## Load the Dataset
#
# We are now going to load the Fashion-MNIST dataset using tensorflow_datasets as we've done before. In this case, however, we are going to define how to split the dataset ourselves. We are going to split the dataset such that 60\% of the data will be used for training, 20\% of the data will be used for validation, and the remaining 20\% of the data will be used for testing.
#
# To do this, we are going to do two things in succession. First we are going to combine (merge) the `train` and `test` splits. After the splits are merged into a single set, we are going to sub-split it into three sets, where the first set has 60\% of the data, the second set has 20\% of the data, and the third set has the remaining 20\% of the data.
#
# To merge all the splits of a dataset together, we can use `split=tfds.Split.ALL`. For example,
#
# ```python
# dataset = tfds.load('fashion_mnist', split=tfds.Split.ALL)
# ```
#
# will return a `dataset` that contains a single set with 70,000 examples. This is because the Fashion-MNIST dataset has a `train` split with 60,000 examples and a `test` split with 10,000 examples. The `tfds.Split.ALL` keyword merged both splits into a single set containing the combined data from both splits.
#
# After we have merged the splits into a single set, we need to sub-split it. We can sub-split our dataset by using the `.subsplit()` method. There are various ways in which we can use the `.subsplit()` method. Here we are going to sub-split the data by providing the percentage of data we want in each set. To do this we just pass a list with percentages we want in each set. For example,
#
# ```python
# split=['train[:60%]', 'train[:20%]', 'train[:20%]']
# ```
#
# will sub-split our dataset into three sets, where the first set has 60\% of the data, the second set has 20\% of the data, and the third set has the remaining 20\% of the data. A word of **caution**, TensorFlow Datasets does not guarantee the reproducibility of the sub-split operations. That means, that two different users working on the same version of a dataset and using the same sub-split operations could end-up with two different sets of examples. Also, if a user regenerates the data, the sub-splits may no longer be the same. To learn more about `subsplit` and other ways to sub-split your data visit the [Split Documentation](https://www.tensorflow.org/datasets/splits#subsplit).

# %%
splits = ['train[:60%]', 'train[:20%]', 'train[:20%]']

dataset, dataset_info = tfds.load('fashion_mnist', split=splits, as_supervised=True, with_info=True)

training_set, validation_set, test_set = dataset

# %% [markdown]
# When we use `split=['train[:60%]', 'train[:20%]', 'train[:20%]']`, `tensorflow_datasets` returns a list with our sub-splits. Since we divided our dataset into 3 sets, then, in this case, `dataset` should be a list with 3 elements.

# %%
# Check that dataset is a tuple
print('dataset has type:', type(dataset))

# Print the number of elements in dataset
print('dataset has {:,} elements '.format(len(dataset)))
# Out:
# dataset has type: <class 'list'>
# dataset has 3 elements

# %%
# Display dataset
dataset
# Out:
# [<PrefetchDataset shapes: ((28, 28, 1), ()), types: (tf.uint8, tf.int64)>,
#  <PrefetchDataset shapes: ((28, 28, 1), ()), types: (tf.uint8, tf.int64)>,
#  <PrefetchDataset shapes: ((28, 28, 1), ()), types: (tf.uint8, tf.int64)>]

# %%
# Display dataset_info
dataset_info
# Out:
# tfds.core.DatasetInfo(
#     name='fashion_mnist',
#     full_name='fashion_mnist/3.0.1',
#     description="""
#     Fashion-MNIST is a dataset of Zalando's article images consisting of a training set of 60,000 examples and a test set of 10,000 examples. Each example is a 28x28 grayscale image, associated with a label from 10 classes.
#     """,
#     homepage='https://github.com/zalandoresearch/fashion-mnist',
#     data_path='C:\\Users\\David\\tensorflow_datasets\\fashion_mnist\\3.0.1',
#     download_size=29.45 MiB,
#     dataset_size=36.42 MiB,
#     features=FeaturesDict({
#         'image': Image(shape=(28, 28, 1), dtype=tf.uint8),
#         'label': ClassLabel(shape=(), dtype=tf.int64, num_classes=10),
#     }),
#     supervised_keys=('image', 'label'),
#     splits={
#         'test': <SplitInfo num_examples=10000, num_shards=1>,
#         'train': <SplitInfo num_examples=60000, num_shards=1>,
#     },
#     citation="""@article{DBLP:journals/corr/abs-1708-07747,
#       author    = {Han Xiao and
#                    Kashif Rasul and
#                    Roland Vollgraf},
#       title     = {Fashion-MNIST: a Novel Image Dataset for Benchmarking Machine Learning
#                    Algorithms},
#       journal   = {CoRR},
#       volume    = {abs/1708.07747},
#       year      = {2017},
#       url       = {http://arxiv.org/abs/1708.07747},
#       archivePrefix = {arXiv},
#       eprint    = {1708.07747},
#       timestamp = {Mon, 13 Aug 2018 16:47:27 +0200},
#       biburl    = {https://dblp.org/rec/bib/journals/corr/abs-1708-07747},
#       bibsource = {dblp computer science bibliography, https://dblp.org}
#     }""",
# )

# %% [markdown]
# ## Explore the Dataset

# %%
total_examples = dataset_info.splits['train'].num_examples + dataset_info.splits['test'].num_examples

num_training_examples = (total_examples * train_split) // 100
num_validation_examples = (total_examples * test_val_split) // 100
num_test_examples = num_validation_examples

print('There are {:,} images in the training set'.format(num_training_examples))
print('There are {:,} images in the validation set'.format(num_validation_examples))
print('There are {:,} images in the test set'.format(num_test_examples))
# Out:
# There are 42,000 images in the training set
# There are 14,000 images in the validation set
# There are 14,000 images in the test set

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 
               'Sandal',      'Shirt',   'Sneaker',  'Bag',   'Ankle boot']

# %% [markdown]
# ## Create Pipeline

# %%
def normalize(image, label):
    image = tf.cast(image, tf.float32)
    image /= 255
    return image, label

batch_size = 64

training_batches = training_set.cache().shuffle(num_training_examples//4).batch(batch_size).map(normalize).prefetch(1)
validation_batches = validation_set.cache().batch(batch_size).map(normalize).prefetch(1)
testing_batches = test_set.cache().batch(batch_size).map(normalize).prefetch(1)

# %% [markdown]
# ## Build the Model
#
# Here we'll build and compile our model as usual.

# %%
model = tf.keras.Sequential([
        tf.keras.layers.Flatten(input_shape=(28,28,1)),
        tf.keras.layers.Dense(256, activation = 'relu'),
        tf.keras.layers.Dense(128, activation = 'relu'),
        tf.keras.layers.Dense(64, activation = 'relu'),
        tf.keras.layers.Dense(10, activation = 'softmax')
])

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# ## Evaluate Loss and Accuracy on the Test Set
#
# The goal of validation is to measure the model's performance on data that isn't part of the training set. Performance here is up to the developer to define though. Typically this is just accuracy, the percentage of classes the network predicted correctly. Other options are [precision and recall](https://en.wikipedia.org/wiki/Precision_and_recall#Definition_(classification_context)) and top-5 error rate. We'll focus on accuracy here. Let's see how the model performs on our test set.

# %%
loss, accuracy = model.evaluate(testing_batches)

print('\nLoss on the TEST Set: {:,.3f}'.format(loss))
print('Accuracy on the TEST Set: {:.3%}'.format(accuracy))
# Out:
# 188/188 [==============================] - 0s 1ms/step - loss: 2.3954 - accuracy: 0.0960
#
# Loss on the TEST Set: 2.390
# Accuracy on the TEST Set: 9.742%

# %% [markdown]
# The network is untrained so it's making random guesses and we should see an accuracy around 10%.

# %% [markdown]
# ## Train the Model with the Validation Set
#
# Now let's train our network as usual, but this time we are also going to incorporate our validation set into the training process.
#
# During training, the model will only use the training set in order to decide how to modify its weights and biases. Then, after every training epoch we calculate the loss on the training and validation sets. These metrics tell us how well our model is "learning" because it they show how well the model generalizes to data that is not used for training. It's important to remember that the model does not use any part of the validation set to tune its weights and biases, therefore it can tell us if we're overfitting the training set.
#
# We can incorporate our validation set into the training process by including the `validation_data=validation_batches` argument in the `.fit` method.

# %%
EPOCHS = 30

history = model.fit(training_batches,
                    epochs = EPOCHS,
                    validation_data=validation_batches)
# Out:
# Epoch 1/30
# 563/563 [==============================] - 2s 2ms/step - loss: 0.5628 - accuracy: 0.7991 - val_loss: 0.4143 - val_accuracy: 0.8503
# Epoch 2/30
# 563/563 [==============================] - 1s 2ms/step - loss: 0.3916 - accuracy: 0.8575 - val_loss: 0.3700 - val_accuracy: 0.8677
# Epoch 3/30
# 563/563 [==============================] - 1s 2ms/step - loss: 0.3571 - accuracy: 0.8687 - val_loss: 0.3207 - val_accuracy: 0.8867
# Epoch 4/30
# 563/563 [==============================] - 1s 2ms/step - loss: 0.3328 - accuracy: 0.8758 - val_loss: 0.3081 - val_accuracy: 0.8880
# Epoch 5/30
# 563/563 [==============================] - 1s 2ms/step - loss: 0.3099 - accuracy: 0.8859 - val_loss: 0.2932 - val_accuracy: 0.8890
# Epoch 6/30
# 563/563 [==============================] - 1s 2ms/step - loss: 0.2946 - accuracy: 0.8898 - val_loss: 0.3242 - val_accuracy: 0.8733
# Epoch 7/30
# 563/563 [==============================] - 1s 2ms/step - loss: 0.2810 - accuracy: 0.8954 - val_loss: 0.2528 - val_accuracy: 0.9059
# Epoch 8/30
# 563/563 [==============================] - 1s 2ms/step - loss: 0.2654 - accuracy: 0.9019 - val_loss: 0.2512 - val_accuracy: 0.9058
# Epoch 9/30
# 563/563 [==============================] - 1s 2ms/step - loss: 0.2572 - accuracy: 0.9027 - val_loss: 0.2335 - val_accuracy: 0.9128
# Epoch 10/30
# 563/563 [==============================] - 1s 2ms/step - loss: 0.2415 - accuracy: 0.9089 - val_loss: 0.2345 - val_accuracy: 0.9087
# Epoch 11/30
# 563/563 [==============================] - 1s 2ms/step - loss: 0.2331 - accuracy: 0.9114 - val_loss: 0.2067 - val_accuracy: 0.9236
# Epoch 12/30
# 563/563 [==============================] - 1s 2ms/step - loss: 0.2225 - accuracy: 0.9162 - val_loss: 0.2114 - val_accuracy: 0.9193
# Epoch 13/30
# 563/563 [==============================] - 1s 2ms/step - loss: 0.2166 - accuracy: 0.9178 - val_loss: 0.2126 - val_accuracy: 0.9191
# Epoch 14/30
# 563/563 [==============================] - 1s 2ms/step - loss: 0.2098 - accuracy: 0.9197 - val_loss: 0.2086 - val_accuracy: 0.9218
# Epoch 15/30
# 563/563 [==============================] - 1s 2ms/step - loss: 0.2015 - accuracy: 0.9233 - val_loss: 0.1863 - val_accuracy: 0.9301
# Epoch 16/30
# 563/563 [==============================] - 1s 2ms/step - loss: 0.1955 - accuracy: 0.9257 - val_loss: 0.1901 - val_accuracy: 0.9277
# Epoch 17/30
# 563/563 [==============================] - 1s 2ms/step - loss: 0.1938 - accuracy: 0.9266 - val_loss: 0.1879 - val_accuracy: 0.9308
# Epoch 18/30
# 563/563 [==============================] - 1s 2ms/step - loss: 0.1812 - accuracy: 0.9306 - val_loss: 0.1631 - val_accuracy: 0.9398
# Epoch 19/30
# 563/563 [==============================] - 1s 2ms/step - loss: 0.1753 - accuracy: 0.9328 - val_loss: 0.1660 - val_accuracy: 0.9413
# Epoch 20/30
# 563/563 [==============================] - 1s 2ms/step - loss: 0.1723 - accuracy: 0.9350 - val_loss: 0.1773 - val_accuracy: 0.9374
# Epoch 21/30
# 563/563 [==============================] - 1s 2ms/step - loss: 0.1676 - accuracy: 0.9355 - val_loss: 0.1611 - val_accuracy: 0.9346
# Epoch 22/30
# 563/563 [==============================] - 1s 2ms/step - loss: 0.1569 - accuracy: 0.9391 - val_loss: 0.1535 - val_accuracy: 0.9417
# Epoch 23/30
# 563/563 [==============================] - 1s 2ms/step - loss: 0.1518 - accuracy: 0.9429 - val_loss: 0.1390 - val_accuracy: 0.9461
# Epoch 24/30
# 563/563 [==============================] - 1s 2ms/step - loss: 0.1462 - accuracy: 0.9433 - val_loss: 0.1482 - val_accuracy: 0.9436
# Epoch 25/30
# 563/563 [==============================] - 1s 2ms/step - loss: 0.1433 - accuracy: 0.9446 - val_loss: 0.1323 - val_accuracy: 0.9492
# Epoch 26/30
# 563/563 [==============================] - 1s 2ms/step - loss: 0.1456 - accuracy: 0.9444 - val_loss: 0.1443 - val_accuracy: 0.9456
# Epoch 27/30
# 563/563 [==============================] - 1s 2ms/step - loss: 0.1363 - accuracy: 0.9473 - val_loss: 0.1264 - val_accuracy: 0.9520
# Epoch 28/30
# 563/563 [==============================] - 1s 2ms/step - loss: 0.1325 - accuracy: 0.9499 - val_loss: 0.1392 - val_accuracy: 0.9458
# Epoch 29/30
# 563/563 [==============================] - 1s 2ms/step - loss: 0.1299 - accuracy: 0.9497 - val_loss: 0.1064 - val_accuracy: 0.9582
# Epoch 30/30
# 563/563 [==============================] - 1s 2ms/step - loss: 0.1287 - accuracy: 0.9508 - val_loss: 0.1500 - val_accuracy: 0.9405

# %% [markdown]
# ## Loss and Validation Plots
#
# If we look at the training and validation losses achieved on epoch 30 above, we see that the loss on the training set is much lower than that achieved on the validation set. This is a clear sign of overfitting. In other words, our model has "memorized" the training set so it performs really well on it, but when tested on data that it wasn't trained on (*i.e.* the validation dataset) it performs poorly.
#
# Let's take a look at the model's loss and accuracy values obtained during training on both the training set and the validation set. This will allow us to see how well or how bad our model is "learning". We can do this easily by using the `history` object returned by the `.fit` method. The  `history.history` attribute is a **dictionary** with a record of training accuracy and loss values at successive epochs, as well as validation accuracy and loss values when applicable.

# %%
# Check that history.history is a dictionary
print('history.history has type:', type(history.history))

# Print the keys of the history.history dictionary
print('\nThe keys of history.history are:', list(history.history.keys()))
# Out:
# history.history has type: <class 'dict'>
#
# The keys of history.history are: ['loss', 'accuracy', 'val_loss', 'val_accuracy']

# %% [markdown]
# Let's use the `history.history` dictionary to plot our model's loss and accuracy values obtained during training.

# %%
training_accuracy = history.history['accuracy']
validation_accuracy = history.history['val_accuracy']

training_loss = history.history['loss']
validation_loss = history.history['val_loss']

epochs_range=range(EPOCHS)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, training_accuracy, label='Training Accuracy')
plt.plot(epochs_range, validation_accuracy, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, training_loss, label='Training Loss')
plt.plot(epochs_range, validation_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# ## Early Stopping
#
# If we look at the training and validation losses as we train the network, we can see a phenomenon known as overfitting.
# This happens when our model performs really well on the training data but it fails to generalize well enough to also perform well on the validation set. We can tell that this is happening because when we finished training the validation loss is higher than the training loss.
#
# One way to prevent our model from overfitting is by stopping training when we achieve the lowest validation loss. If we take a look at the plots we can see that at the beginning of training the validation loss starts decreasing, then after some epochs it levels off, and then it just starts increasing. Therefore, we can stop training our model when the validation loss levels off, such that our network is accurate but it's not overfitting.
#
# This strategy is called **early-stopping**. We can implement early stopping in `tf.keras` by using a **callback**. A callback is a set of functions to be applied at given stages of the training process. You can pass a list of callbacks to the `.fit()` method by using the `callbacks` keyword argument.
#
# To implement early-stopping during training we will use the callback:
#
#
# ```python
# tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5)
# ```
#
# The `monitor` argument specifies the quantity we want to monitor during training to determine when to stop training. The `patience` argument determines the number of consecutive epochs with no significant improvement after which training will be stopped. We can also specify the minimum change in the monitored quantity to qualify as an improvement, by specifying the `min_delta` argument. For more information on the early-stopping callback check out the [EarlyStopping
# documentation](https://www.tensorflow.org/versions/r2.0/api_docs/python/tf/keras/callbacks/EarlyStopping#class_earlystopping).

# %%
model = tf.keras.Sequential([
        tf.keras.layers.Flatten(input_shape=(28,28,1)),
        tf.keras.layers.Dense(256, activation = 'relu'),
        tf.keras.layers.Dense(128, activation = 'relu'),
        tf.keras.layers.Dense(64, activation = 'relu'),
        tf.keras.layers.Dense(10, activation = 'softmax')
])

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# Stop training when there is no improvement in the validation loss for 5 consecutive epochs
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5)

history = model.fit(training_batches,
                    epochs = 100,
                    validation_data=validation_batches,
                    callbacks=[early_stopping])
# Out:
# Epoch 1/100
# 563/563 [==============================] - 1s 2ms/step - loss: 0.7221 - accuracy: 0.7444 - val_loss: 0.4153 - val_accuracy: 0.8493
# Epoch 2/100
# 563/563 [==============================] - 1s 2ms/step - loss: 0.4039 - accuracy: 0.8532 - val_loss: 0.3963 - val_accuracy: 0.8560
# Epoch 3/100
# 563/563 [==============================] - 1s 2ms/step - loss: 0.3557 - accuracy: 0.8697 - val_loss: 0.3275 - val_accuracy: 0.8773
# Epoch 4/100
# 563/563 [==============================] - 1s 2ms/step - loss: 0.3280 - accuracy: 0.8779 - val_loss: 0.2998 - val_accuracy: 0.8917
# Epoch 5/100
# 563/563 [==============================] - 1s 2ms/step - loss: 0.3143 - accuracy: 0.8841 - val_loss: 0.2760 - val_accuracy: 0.9007
# Epoch 6/100
# 563/563 [==============================] - 1s 2ms/step - loss: 0.2955 - accuracy: 0.8911 - val_loss: 0.2938 - val_accuracy: 0.8909
# Epoch 7/100
# 563/563 [==============================] - 1s 2ms/step - loss: 0.2845 - accuracy: 0.8945 - val_loss: 0.2860 - val_accuracy: 0.8915
# Epoch 8/100
# 563/563 [==============================] - 1s 2ms/step - loss: 0.2638 - accuracy: 0.9026 - val_loss: 0.2500 - val_accuracy: 0.9066
# Epoch 9/100
# 563/563 [==============================] - 1s 2ms/step - loss: 0.2544 - accuracy: 0.9057 - val_loss: 0.2290 - val_accuracy: 0.9139
# Epoch 10/100
# 563/563 [==============================] - 1s 2ms/step - loss: 0.2535 - accuracy: 0.9038 - val_loss: 0.2222 - val_accuracy: 0.9190
# Epoch 11/100
# 563/563 [==============================] - 1s 2ms/step - loss: 0.2379 - accuracy: 0.9090 - val_loss: 0.2343 - val_accuracy: 0.9100
# Epoch 12/100
# 563/563 [==============================] - 1s 2ms/step - loss: 0.2298 - accuracy: 0.9142 - val_loss: 0.2026 - val_accuracy: 0.9243
# Epoch 13/100
# 563/563 [==============================] - 1s 2ms/step - loss: 0.2175 - accuracy: 0.9174 - val_loss: 0.2003 - val_accuracy: 0.9266
# Epoch 14/100
# 563/563 [==============================] - 1s 2ms/step - loss: 0.2108 - accuracy: 0.9205 - val_loss: 0.2102 - val_accuracy: 0.9179
# Epoch 15/100
# 563/563 [==============================] - 1s 2ms/step - loss: 0.2021 - accuracy: 0.9222 - val_loss: 0.1903 - val_accuracy: 0.9278
# Epoch 16/100
# 563/563 [==============================] - 1s 2ms/step - loss: 0.1981 - accuracy: 0.9247 - val_loss: 0.1888 - val_accuracy: 0.9302
# Epoch 17/100
# 563/563 [==============================] - 1s 2ms/step - loss: 0.1916 - accuracy: 0.9282 - val_loss: 0.1805 - val_accuracy: 0.9313
# Epoch 18/100
# 563/563 [==============================] - 1s 2ms/step - loss: 0.1817 - accuracy: 0.9303 - val_loss: 0.1728 - val_accuracy: 0.9358
# Epoch 19/100
# 563/563 [==============================] - ETA: 0s - loss: 0.1746 - accuracy: 0.93 - 1s 2ms/step - loss: 0.1746 - accuracy: 0.9340 - val_loss: 0.1555 - val_accuracy: 0.9398
# Epoch 20/100
# 563/563 [==============================] - 1s 2ms/step - loss: 0.1711 - accuracy: 0.9349 - val_loss: 0.1641 - val_accuracy: 0.9410
# Epoch 21/100
# 563/563 [==============================] - 1s 2ms/step - loss: 0.1654 - accuracy: 0.9382 - val_loss: 0.1512 - val_accuracy: 0.9441
# Epoch 22/100
# 563/563 [==============================] - 1s 2ms/step - loss: 0.1546 - accuracy: 0.9410 - val_loss: 0.1824 - val_accuracy: 0.9306
# Epoch 23/100
# 563/563 [==============================] - 1s 2ms/step - loss: 0.1585 - accuracy: 0.9382 - val_loss: 0.1479 - val_accuracy: 0.9454
# Epoch 24/100
# 563/563 [==============================] - 1s 2ms/step - loss: 0.1595 - accuracy: 0.9398 - val_loss: 0.1385 - val_accuracy: 0.9468
# Epoch 25/100
# 563/563 [==============================] - 1s 2ms/step - loss: 0.1469 - accuracy: 0.9439 - val_loss: 0.1277 - val_accuracy: 0.9523
# Epoch 26/100
# 563/563 [==============================] - 1s 2ms/step - loss: 0.1362 - accuracy: 0.9465 - val_loss: 0.1258 - val_accuracy: 0.9514
# Epoch 27/100
# 563/563 [==============================] - 1s 2ms/step - loss: 0.1370 - accuracy: 0.9468 - val_loss: 0.1174 - val_accuracy: 0.9562
# Epoch 28/100
# 563/563 [==============================] - 1s 2ms/step - loss: 0.1254 - accuracy: 0.9531 - val_loss: 0.1199 - val_accuracy: 0.9538
# Epoch 29/100
# 563/563 [==============================] - 1s 2ms/step - loss: 0.1276 - accuracy: 0.9506 - val_loss: 0.1301 - val_accuracy: 0.9518
# Epoch 30/100
# 563/563 [==============================] - 1s 2ms/step - loss: 0.1218 - accuracy: 0.9533 - val_loss: 0.1439 - val_accuracy: 0.9467 loss: 0.1217 -
# Epoch 31/100
# 563/563 [==============================] - 1s 2ms/step - loss: 0.1274 - accuracy: 0.9521 - val_loss: 0.1109 - val_accuracy: 0.9572
# Epoch 32/100
# 563/563 [==============================] - 1s 2ms/step - loss: 0.1180 - accuracy: 0.9559 - val_loss: 0.0988 - val_accuracy: 0.9613
# Epoch 33/100
# 563/563 [==============================] - 1s 2ms/step - loss: 0.1108 - accuracy: 0.9576 - val_loss: 0.1210 - val_accuracy: 0.9508
# Epoch 34/100
# 563/563 [==============================] - 1s 2ms/step - loss: 0.1106 - accuracy: 0.9566 - val_loss: 0.1083 - val_accuracy: 0.9582
# Epoch 35/100
# 563/563 [==============================] - 1s 2ms/step - loss: 0.1154 - accuracy: 0.9556 - val_loss: 0.0988 - val_accuracy: 0.9631
# Epoch 36/100
# 563/563 [==============================] - 1s 2ms/step - loss: 0.1001 - accuracy: 0.9608 - val_loss: 0.1164 - val_accuracy: 0.9559
# Epoch 37/100
# 563/563 [==============================] - 1s 2ms/step - loss: 0.0949 - accuracy: 0.9626 - val_loss: 0.1027 - val_accuracy: 0.9601

# %%
training_accuracy = history.history['accuracy']
validation_accuracy = history.history['val_accuracy']

training_loss = history.history['loss']
validation_loss = history.history['val_loss']

epochs_range=range(len(training_accuracy))

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, training_accuracy, label='Training Accuracy')
plt.plot(epochs_range, validation_accuracy, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, training_loss, label='Training Loss')
plt.plot(epochs_range, validation_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# ## Dropout
#
# Another common method to reduce overfitting is called **dropout**, where we randomly drop neurons in our model during training. This forces the network to share information between weights, increasing its ability to generalize to new data. We can implement dropout in `tf.keras` by adding `tf.keras.layers.Dropout()` layers to our models.
#
# ```python
# tf.keras.layers.Dropout(rate)
# ```
# randomly sets a fraction `rate` of the dropout layer's input units to 0 at each update during training. The `rate` argument is a float between 0 and 1, that determines the fraction of neurons from the previous layer that should be turned off. For example,  `rate =0.5` will drop 50\% of the neurons.
#
# It's important to note that we should never apply dropout to the input layer of our network. Also, remember that during training we want to use dropout to prevent overfitting, but during inference we want to use all the neurons in the network. `tf.keras` is designed to care of this automatically, so it uses the dropout layers during training, but automatically ignores them during inference.

# %% [markdown]
# > **Exercise:** Add 3 dropout layers with a `rate=0.2` to our previous `model` and train it on Fashion-MNIST again. See if you can get a lower validation loss.

# %%
## Solution
model = tf.keras.Sequential([
        tf.keras.layers.Flatten(input_shape=(28,28,1)),
        tf.keras.layers.Dense(256, activation = 'relu'),
        tf.keras.layers.Dropout(0.2),
        tf.keras.layers.Dense(128, activation = 'relu'),
        tf.keras.layers.Dropout(0.2),
        tf.keras.layers.Dense(64, activation = 'relu'),
        tf.keras.layers.Dropout(0.2),
        tf.keras.layers.Dense(10, activation = 'softmax')
])

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# Stop training when there is no improvement in the validation loss for 5 consecutive epochs
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5)

history = model.fit(training_batches,
                    epochs = 100,
                    validation_data=validation_batches,
                    callbacks=[early_stopping])
# Out:
# Epoch 1/100
# 563/563 [==============================] - 2s 3ms/step - loss: 0.9642 - accuracy: 0.6514 - val_loss: 0.4293 - val_accuracy: 0.8440
# Epoch 2/100
# 563/563 [==============================] - 1s 2ms/step - loss: 0.4852 - accuracy: 0.8300 - val_loss: 0.3758 - val_accuracy: 0.8602
# Epoch 3/100
# 563/563 [==============================] - 1s 2ms/step - loss: 0.4286 - accuracy: 0.8466 - val_loss: 0.3348 - val_accuracy: 0.8780
# Epoch 4/100
# 563/563 [==============================] - 1s 2ms/step - loss: 0.3934 - accuracy: 0.8583 - val_loss: 0.3350 - val_accuracy: 0.8752
# Epoch 5/100
# 563/563 [==============================] - 1s 2ms/step - loss: 0.3748 - accuracy: 0.8647 - val_loss: 0.3095 - val_accuracy: 0.88420s - loss: 0.3716 - accuracy - ETA: 0s - loss: 0.3736 - accu
# Epoch 6/100
# 563/563 [==============================] - 1s 2ms/step - loss: 0.3553 - accuracy: 0.8701 - val_loss: 0.2978 - val_accuracy: 0.8882
# Epoch 7/100
# 563/563 [==============================] - 1s 2ms/step - loss: 0.3471 - accuracy: 0.8739 - val_loss: 0.2854 - val_accuracy: 0.8938
# Epoch 8/100
# 563/563 [==============================] - 1s 2ms/step - loss: 0.3313 - accuracy: 0.8812 - val_loss: 0.2734 - val_accuracy: 0.8999
# Epoch 9/100
# 563/563 [==============================] - 1s 2ms/step - loss: 0.3234 - accuracy: 0.8835 - val_loss: 0.2781 - val_accuracy: 0.8949: 0s - loss: 0
# Epoch 10/100
# 563/563 [==============================] - 1s 2ms/step - loss: 0.3168 - accuracy: 0.8811 - val_loss: 0.2685 - val_accuracy: 0.9003
# Epoch 11/100
# 563/563 [==============================] - 1s 2ms/step - loss: 0.3042 - accuracy: 0.8893 - val_loss: 0.2675 - val_accuracy: 0.8977
# Epoch 12/100
# 563/563 [==============================] - 1s 2ms/step - loss: 0.3020 - accuracy: 0.8896 - val_loss: 0.2475 - val_accuracy: 0.9055
# Epoch 13/100
# 563/563 [==============================] - 1s 2ms/step - loss: 0.2992 - accuracy: 0.8895 - val_loss: 0.2517 - val_accuracy: 0.9035
# Epoch 14/100
# 563/563 [==============================] - 1s 2ms/step - loss: 0.2901 - accuracy: 0.8925 - val_loss: 0.2432 - val_accuracy: 0.9082
# Epoch 15/100
# 563/563 [==============================] - 1s 2ms/step - loss: 0.2853 - accuracy: 0.8956 - val_loss: 0.2410 - val_accuracy: 0.9073
# Epoch 16/100
# 563/563 [==============================] - 1s 2ms/step - loss: 0.2785 - accuracy: 0.8987 - val_loss: 0.2371 - val_accuracy: 0.9087
# Epoch 17/100
# 563/563 [==============================] - 1s 2ms/step - loss: 0.2769 - accuracy: 0.8967 - val_loss: 0.2367 - val_accuracy: 0.9094
# Epoch 18/100
# 563/563 [==============================] - 1s 2ms/step - loss: 0.2653 - accuracy: 0.9011 - val_loss: 0.2268 - val_accuracy: 0.9111
# Epoch 19/100
# 563/563 [==============================] - 1s 2ms/step - loss: 0.2645 - accuracy: 0.9003 - val_loss: 0.2126 - val_accuracy: 0.9184
# Epoch 20/100
# 563/563 [==============================] - 1s 2ms/step - loss: 0.2611 - accuracy: 0.9016 - val_loss: 0.2178 - val_accuracy: 0.9198
# Epoch 21/100
# 563/563 [==============================] - 1s 2ms/step - loss: 0.2663 - accuracy: 0.9011 - val_loss: 0.2310 - val_accuracy: 0.9086
# Epoch 22/100
# 563/563 [==============================] - 1s 2ms/step - loss: 0.2571 - accuracy: 0.9039 - val_loss: 0.2122 - val_accuracy: 0.9208
# Epoch 23/100
# 563/563 [==============================] - 1s 2ms/step - loss: 0.2447 - accuracy: 0.9108 - val_loss: 0.2017 - val_accuracy: 0.9198
# Epoch 24/100
# 563/563 [==============================] - 1s 2ms/step - loss: 0.2490 - accuracy: 0.9085 - val_loss: 0.2054 - val_accuracy: 0.9218
# Epoch 25/100
# 563/563 [==============================] - 1s 2ms/step - loss: 0.2439 - accuracy: 0.9071 - val_loss: 0.1966 - val_accuracy: 0.9257
# Epoch 26/100
# 563/563 [==============================] - 1s 2ms/step - loss: 0.2368 - accuracy: 0.9107 - val_loss: 0.1991 - val_accuracy: 0.9219- accuracy:
# Epoch 27/100
# 563/563 [==============================] - 1s 2ms/step - loss: 0.2440 - accuracy: 0.9107 - val_loss: 0.1916 - val_accuracy: 0.9248
# Epoch 28/100
# 563/563 [==============================] - 1s 2ms/step - loss: 0.2241 - accuracy: 0.9147 - val_loss: 0.1934 - val_accuracy: 0.9245
# Epoch 29/100
# 563/563 [==============================] - 1s 2ms/step - loss: 0.2208 - accuracy: 0.9155 - val_loss: 0.1794 - val_accuracy: 0.9283
# Epoch 30/100
# 563/563 [==============================] - 1s 2ms/step - loss: 0.2285 - accuracy: 0.9152 - val_loss: 0.1873 - val_accuracy: 0.9305
# Epoch 31/100
# 563/563 [==============================] - 1s 2ms/step - loss: 0.2203 - accuracy: 0.9164 - val_loss: 0.1822 - val_accuracy: 0.9306
# Epoch 32/100
# 563/563 [==============================] - 1s 2ms/step - loss: 0.2227 - accuracy: 0.9185 - val_loss: 0.1860 - val_accuracy: 0.9259
# Epoch 33/100
# 563/563 [==============================] - 1s 2ms/step - loss: 0.2207 - accuracy: 0.9177 - val_loss: 0.1738 - val_accuracy: 0.9320
# Epoch 34/100
# 563/563 [==============================] - 1s 2ms/step - loss: 0.2183 - accuracy: 0.9178 - val_loss: 0.1782 - val_accuracy: 0.9322
# Epoch 35/100
# 563/563 [==============================] - 1s 2ms/step - loss: 0.2193 - accuracy: 0.9164 - val_loss: 0.1767 - val_accuracy: 0.9312
# Epoch 36/100
# 563/563 [==============================] - 1s 2ms/step - loss: 0.2080 - accuracy: 0.9207 - val_loss: 0.1655 - val_accuracy: 0.9361
# Epoch 37/100
# 563/563 [==============================] - 1s 2ms/step - loss: 0.2123 - accuracy: 0.9207 - val_loss: 0.1631 - val_accuracy: 0.9378
# Epoch 38/100
# 563/563 [==============================] - 1s 2ms/step - loss: 0.2049 - accuracy: 0.9236 - val_loss: 0.1558 - val_accuracy: 0.9413
# Epoch 39/100
# 563/563 [==============================] - 1s 2ms/step - loss: 0.2096 - accuracy: 0.9228 - val_loss: 0.1568 - val_accuracy: 0.9384
# Epoch 40/100
# 563/563 [==============================] - 1s 2ms/step - loss: 0.2104 - accuracy: 0.9232 - val_loss: 0.1700 - val_accuracy: 0.9335
# Epoch 41/100
# 563/563 [==============================] - 1s 2ms/step - loss: 0.1998 - accuracy: 0.9251 - val_loss: 0.1526 - val_accuracy: 0.9419
# Epoch 42/100
# 563/563 [==============================] - 1s 2ms/step - loss: 0.2043 - accuracy: 0.9236 - val_loss: 0.1580 - val_accuracy: 0.9391
# Epoch 43/100
# 563/563 [==============================] - 1s 2ms/step - loss: 0.2003 - accuracy: 0.9252 - val_loss: 0.1449 - val_accuracy: 0.9442
# Epoch 44/100
# 563/563 [==============================] - 1s 2ms/step - loss: 0.2028 - accuracy: 0.9264 - val_loss: 0.1520 - val_accuracy: 0.9419
# Epoch 45/100
# 563/563 [==============================] - 1s 3ms/step - loss: 0.1962 - accuracy: 0.9256 - val_loss: 0.1541 - val_accuracy: 0.9383
# Epoch 46/100
# 563/563 [==============================] - 1s 2ms/step - loss: 0.1943 - accuracy: 0.9262 - val_loss: 0.1432 - val_accuracy: 0.9448
# Epoch 47/100
# 563/563 [==============================] - 1s 2ms/step - loss: 0.1890 - accuracy: 0.9278 - val_loss: 0.1523 - val_accuracy: 0.9407
# Epoch 48/100
# 563/563 [==============================] - 1s 2ms/step - loss: 0.1959 - accuracy: 0.9265 - val_loss: 0.1468 - val_accuracy: 0.9431
# Epoch 49/100
# 563/563 [==============================] - 1s 2ms/step - loss: 0.1879 - accuracy: 0.9306 - val_loss: 0.1398 - val_accuracy: 0.9467
# Epoch 50/100
# 563/563 [==============================] - 1s 2ms/step - loss: 0.1821 - accuracy: 0.9325 - val_loss: 0.1318 - val_accuracy: 0.9484
# Epoch 51/100
# 563/563 [==============================] - 1s 2ms/step - loss: 0.1882 - accuracy: 0.9303 - val_loss: 0.1432 - val_accuracy: 0.9435
# Epoch 52/100
# 563/563 [==============================] - 1s 2ms/step - loss: 0.1798 - accuracy: 0.9314 - val_loss: 0.1424 - val_accuracy: 0.9463
# Epoch 53/100
# 563/563 [==============================] - 1s 2ms/step - loss: 0.1830 - accuracy: 0.9329 - val_loss: 0.1366 - val_accuracy: 0.9494
# Epoch 54/100
# 563/563 [==============================] - 1s 2ms/step - loss: 0.1778 - accuracy: 0.9326 - val_loss: 0.1391 - val_accuracy: 0.9458
# Epoch 55/100
# 563/563 [==============================] - 1s 2ms/step - loss: 0.1748 - accuracy: 0.9335 - val_loss: 0.1271 - val_accuracy: 0.9498
# Epoch 56/100
# 563/563 [==============================] - 1s 2ms/step - loss: 0.1707 - accuracy: 0.9369 - val_loss: 0.1281 - val_accuracy: 0.9517
# Epoch 57/100
# 563/563 [==============================] - 1s 2ms/step - loss: 0.1719 - accuracy: 0.9350 - val_loss: 0.1190 - val_accuracy: 0.9564
# Epoch 58/100
# 563/563 [==============================] - 1s 2ms/step - loss: 0.1654 - accuracy: 0.9392 - val_loss: 0.1226 - val_accuracy: 0.9546
# Epoch 59/100
# 563/563 [==============================] - 1s 2ms/step - loss: 0.1734 - accuracy: 0.9351 - val_loss: 0.1193 - val_accuracy: 0.9538
# Epoch 60/100
# 563/563 [==============================] - 1s 2ms/step - loss: 0.1660 - accuracy: 0.9381 - val_loss: 0.1311 - val_accuracy: 0.9486
# Epoch 61/100
# 563/563 [==============================] - 1s 2ms/step - loss: 0.1672 - accuracy: 0.9378 - val_loss: 0.1341 - val_accuracy: 0.9504
# Epoch 62/100
# 563/563 [==============================] - 1s 2ms/step - loss: 0.1683 - accuracy: 0.9362 - val_loss: 0.1217 - val_accuracy: 0.9528 loss:

# %%
training_accuracy = history.history['accuracy']
validation_accuracy = history.history['val_accuracy']

training_loss = history.history['loss']
validation_loss = history.history['val_loss']

epochs_range=range(len(training_accuracy))

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, training_accuracy, label='Training Accuracy')
plt.plot(epochs_range, validation_accuracy, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, training_loss, label='Training Loss')
plt.plot(epochs_range, validation_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# ## Inference
#
# Now that the model is trained, we can use it to perform inference. Here we are going to perform inference on 30 images and print the labels in green if our model's prediction matches the true label. On the other hand, if our model's prediction doesn't match the true label, we print the label in red.

# %%
for image_batch, label_batch in testing_batches.take(1):
    ps = model.predict(image_batch)
    images = image_batch.numpy().squeeze()
    labels = label_batch.numpy()


plt.figure(figsize=(10,15))

for n in range(30):
    plt.subplot(6,5,n+1)
    plt.imshow(images[n], cmap = plt.cm.binary)
    color = 'green' if np.argmax(ps[n]) == labels[n] else 'red'
    plt.title(class_names[np.argmax(ps[n])], color=color)
    plt.axis('off')

# %% [markdown]
# ## Next Up!
#
# In the next lesson, we'll see how to save our trained models. In general, you won't want to train a model every time you need it. Instead, you'll train once, save it, then load the model when you want to train more or use it for inference.
